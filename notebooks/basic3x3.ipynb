# %%
import math
import random
import sys

import matplotlib.pyplot as plt
from IPython.display import HTML
import numpy as np


from orga.orga import Engine
from orga.orga_plots import plot_animation

from examples import basic_model as model

# %%
GRAPH_D = 3
GRAPH_K = 3
ITERATIONS = 10
random.seed(42)  # for debugging repeatability

# %%
random.seed(42)

engine = Engine(model.generate_employee, graph_k=GRAPH_K, graph_d=GRAPH_D)

fig, ax = plt.subplots(figsize=(10, 5))

ax.tick_params(
    axis='both', left='off', top='off', right='off', bottom='off',
    labelleft='off', labeltop='off', labelright='off', labelbottom='off')
    

anim = plot_animation(fig, ax, engine, ITERATIONS)

HTML(anim.to_html5_video())
# Out:
# <video width="720" height="360" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
